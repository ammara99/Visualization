# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
    
data = pd.read_csv('fifa.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
def country(x):
    return data[data['Nationality'] == x][['Name','Overall','Potential','Position']]

country('Iran')
# Out:
#                   Name  Overall  Potential Position
# 963     A. Jahanbakhsh       77         80       RM
# 1606     K. Ansarifard       75         75       ST
# 2090        S. Ghoddos       74         79       LM
# 3150         K. Rezaei       73         75       ST
# 3541      A. Abedzadeh       72         77       GK
# 5055   M. Pouraliganji       70         73      RCB
# 5976     A. Gholizadeh       69         76       RM
# 6165     S. Beitashour       69         69       RB
# 6698      S. Ezatolahi       68         79       CM
# 6747      S. Moharrami       68         75       RB
# 7104          V. Amiri       68         68       LW
# 7187      O. Noorafkan       68         76      CDM
# 8798     F. Ahmadzadeh       66         67       RM
# 11087       A. Etemadi       64         64       GK
# 11249        M. Naderi       64         73       LB
# 11718        D. Davari       64         64       GK
# 14202      M. Hosseini       61         67      LCB

# %%
def club(x):
    return data[data['Club'] == x][['Name','Jersey Number','Position','Overall','Nationality','Age','Wage',
                                    'Value','Contract Valid Until']]

club('Chelsea')
# Out:
#                       Name  Jersey Number Position  Overall  Nationality  Age  \
# 5                E. Hazard           10.0       LF       91      Belgium   27
# 14                N. Kanté           13.0      LDM       89       France   27
# 69             Azpilicueta           14.0       RB       86        Spain   28
# 121               Jorginho            8.0       CM       84        Italy   26
# 140                Willian           22.0       RW       84       Brazil   29
# 176             M. Kovačić           17.0      LCM       83      Croatia   24
# 177                   Kepa           13.0       GK       83        Spain   23
# 200          Marcos Alonso            3.0       LB       83        Spain   27
# 209             David Luiz           30.0      LCB       83       Brazil   31
# 219          Cesc Fàbregas            4.0       CM       83        Spain   31
# 257             A. Rüdiger           16.0       CB       82      Germany   25
# 265                 Morata            7.0       ST       82        Spain   25
# 283                  Pedro           11.0       RW       82        Spain   30
# 304              O. Giroud            9.0       ST       82       France   31
# 336         A. Christensen            6.0      LCB       81      Denmark   22
# 534              G. Cahill           24.0       CB       80      England   32
# 590          D. Zappacosta           21.0       RB       79        Italy   26
# 641          M. van Ginkel           26.0       CM       79  Netherlands   25
# 646             R. Barkley           15.0      CAM       79      England   24
# 681          D. Drinkwater            6.0       CM       79      England   28
# 858               V. Moses           15.0       RW       78      Nigeria   27
# 1085       R. Loftus-Cheek           12.0       CM       77      England   22
# 1287          W. Caballero           13.0       GK       76    Argentina   36
# 1664               Emerson           33.0       LB       75        Italy   23
# 3311          Lucas Piazon           34.0       RW       72       Brazil   24
# 3937              R. Green           31.0       GK       72      England   38
# 5121        C. Hudson-Odoi           20.0       LW       70      England   17
# 10801            E. Ampadu           15.0      LDM       65        Wales   17
# 14603           B. Gilmour           60.0       CM       61     Scotland   17
# 14646  M. Taylor-Crossdale           56.0       ST       61      England   18
# 15322         G. McEachran           55.0      CAM       59      England   17
# 15846             M. Guehi           53.0       CB       58      England   17
# 16806             M. Bulka           59.0       GK       56       Poland   18
#
#         Wage   Value Contract Valid Until
# 5      €340K    €93M                 2020
# 14     €225K    €63M                 2023
# 69     €175K    €35M                 2022
# 121    €155K    €38M                 2023
# 140    €175K  €30.5M                 2020
# 176    €165K    €35M         Jun 30, 2019
# 177     €84K  €28.5M                 2025
# 200    €130K    €24M                 2023
# 209    €130K  €17.5M                 2019
# 219    €140K    €22M                 2019
# 257    €110K  €22.5M                 2022
# 265    €135K  €28.5M                 2022
# 283    €140K    €21M                 2020
# 304    €140K    €20M                 2019
# 336     €91K  €21.5M                 2022
# 534     €99K   €8.5M                 2019
# 590     €94K  €12.5M                 2021
# 641     €98K  €14.5M                 2020
# 646     €89K    €16M                 2023
# 681    €110K  €12.5M                 2022
# 858    €105K    €11M                 2021
# 1085    €76K    €13M                 2021
# 1287    €39K     €1M                 2019
# 1664    €61K     €7M                 2022
# 3311    €55K   €4.2M                 2020
# 3937    €28K   €210K                 2019
# 5121    €25K   €3.5M                 2020
# 10801    €8K   €1.1M                 2023
# 14603    €7K   €550K                 2021
# 14646    €8K   €525K                 2019
# 15322    €6K   €350K                 2019
# 15846    €4K   €230K                 2020
# 16806    €2K   €150K                 2019

# %%
x = club('Chelsea')
x.shape
# Out:
# (33, 9)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
data['ShortPassing'].fillna(data['ShortPassing'].mean(), inplace = True)
data['Volleys'].fillna(data['Volleys'].mean(), inplace = True)
data['Dribbling'].fillna(data['Dribbling'].mean(), inplace = True)
data['Curve'].fillna(data['Curve'].mean(), inplace = True)
data['FKAccuracy'].fillna(data['FKAccuracy'], inplace = True)
data['LongPassing'].fillna(data['LongPassing'].mean(), inplace = True)
data['BallControl'].fillna(data['BallControl'].mean(), inplace = True)
data['HeadingAccuracy'].fillna(data['HeadingAccuracy'].mean(), inplace = True)
data['Finishing'].fillna(data['Finishing'].mean(), inplace = True)
data['Crossing'].fillna(data['Crossing'].mean(), inplace = True)
data['Weight'].fillna('200lbs', inplace = True)
data['Contract Valid Until'].fillna(2019, inplace = True)
data['Height'].fillna("5'11", inplace = True)
data['Loaned From'].fillna('None', inplace = True)
data['Joined'].fillna('Jul 1, 2018', inplace = True)
data['Jersey Number'].fillna(8, inplace = True)
data['Body Type'].fillna('Normal', inplace = True)
data['Position'].fillna('ST', inplace = True)
data['Club'].fillna('No Club', inplace = True)
data['Work Rate'].fillna('Medium/ Medium', inplace = True)
data['Skill Moves'].fillna(data['Skill Moves'].median(), inplace = True)
data['Weak Foot'].fillna(3, inplace = True)
data['Preferred Foot'].fillna('Right', inplace = True)
data['International Reputation'].fillna(1, inplace = True)
data['Wage'].fillna('€200K', inplace = True)

# %%
data.fillna(0, inplace = True)

# %%
plt.rcParams['figure.figsize'] = (10, 5)
sns.countplot(data['Preferred Foot'], palette = 'bone')
plt.title('Most Preferred Foot of the Players', fontsize = 20)
plt.show()
# Out:
# C:\Users\Ammara\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (18, 8))
plt.style.use('fivethirtyeight')
ax = sns.countplot('Position', data = data, palette = 'pink')
ax.set_xlabel(xlabel = 'Different Positions in Football', fontsize = 16)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 16)
ax.set_title(label = 'Comparison of Positions and Players', fontsize = 20)
plt.show()
# Out:
# C:\Users\Ammara\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
def extract_value_from(value):
  out = value.replace('lbs', '')
  return float(out)
data['Weight'] = data['Weight'].apply(lambda x : extract_value_from(x))

# %%
def extract_value_from(Value):
    out = Value.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000000
    elif 'K' in Value:
        out = float(out.replace('K', ''))*1000
    return float(out)

# %%
data['Value'] = data['Value'].apply(lambda x: extract_value_from(x))
data['Wage'] = data['Wage'].apply(lambda x: extract_value_from(x))

# %%
plt.figure(figsize = (13, 8))
ax = sns.countplot(x = 'Height', data = data, palette = 'dark')
ax.set_title(label = 'Height Count of players', fontsize = 20)
ax.set_xlabel(xlabel = 'Height in Foot per inch', fontsize = 16)
ax.set_ylabel(ylabel = 'Count', fontsize = 16)
plt.show()

# %%
plt.figure(figsize = (20, 5))
plt.style.use('classic')
sns.distplot(data['Weight'], color = 'blue')
plt.title('FIFA 19 players weight', fontsize = 20)
plt.xlabel('Heights associated with the players', fontsize = 16)
plt.ylabel('count of Players', fontsize = 16)
plt.show()
# Out:
# C:\Users\Ammara\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.style.use('dark_background')
data['Nationality'].value_counts().head(80).plot.bar(color = 'orange', figsize = (20, 7))
plt.title('Different Nations in FIFA 2019', fontsize = 30, fontweight = 20)
plt.xlabel('Name of The Country')
plt.ylabel('count')
plt.show()

# %%
selected_columns = ['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
                    'Wage', 'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot',
                    'Skill Moves', 'Work Rate', 'Body Type', 'Position', 'Height', 'Weight',
                    'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
                    'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
                    'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
                    'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
                    'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
                    'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
                    'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause']

data_selected = pd.DataFrame(data, columns = selected_columns)
data_selected.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Special', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Position',
#        'Height', 'Weight', 'Finishing', 'HeadingAccuracy', 'ShortPassing',
#        'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing',
#        'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions',
#        'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Release Clause'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize'] = (20, 7)
plt.style.use('seaborn-dark-palette')

sns.boxenplot(data['Overall'], data['Age'], hue = data['Preferred Foot'], palette = 'Greys')
plt.title('Comparison of Overall Scores and age wrt Preferred foot', fontsize = 20)
plt.show()
#violin plot goals against age
# Out:
# C:\Users\Ammara\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Columbia')
data_countries = data.loc[data['Nationality'].isin(some_countries) & data['Overall']]

plt.rcParams['figure.figsize'] = (15, 7)
ax = sns.barplot(x = data_countries['Nationality'], y = data_countries['Overall'], palette = 'spring')
ax.set_xlabel(xlabel = 'Countries', fontsize = 9)
ax.set_ylabel(ylabel = 'Overall Scores', fontsize = 9)
ax.set_title(label = 'Distribution of overall scores of players from different countries', fontsize = 20)
plt.show()

# %%
sns.set(style = "dark", palette = "colorblind", color_codes = True)
x = data.Age
plt.figure(figsize = (15,8))
ax = sns.distplot(x, bins = 58, kde = False, color = 'g')
ax.set_xlabel(xlabel = "Player\'s age", fontsize = 16)
ax.set_ylabel(ylabel = 'Number of players', fontsize = 16)
ax.set_title(label = 'Histogram of players age', fontsize = 20)
plt.show()
# Out:
# C:\Users\Ammara\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
some_countries = ('England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy', 'Columbia')
data_countries = data.loc[data['Nationality'].isin(some_countries) & data['Wage']]

plt.rcParams['figure.figsize'] = (15, 7)
ax = sns.barplot(x = data_countries['Nationality'], y = data_countries['Wage'], palette = 'Purples')
ax.set_xlabel(xlabel = 'Countries', fontsize = 9)
ax.set_ylabel(ylabel = 'Wage', fontsize = 9)
ax.set_title(label = 'Wage of athletes for different nations', fontsize = 15)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 8)
ax = sns.barplot(x = 'Club', y = 'Age', data = data_club, palette = 'magma')
ax.set_xlabel(xlabel = 'Names of some popular Clubs', fontsize = 10)
ax.set_ylabel(ylabel = 'Distribution', fontsize = 10)
ax.set_title(label = 'Disstribution of Ages in some Popular Clubs', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-e77c4c2953f4> in <module>
#       1 plt.rcParams['figure.figsize'] = (15, 8)
# ----> 2 ax = sns.barplot(x = 'Club', y = 'Age', data = data_club, palette = 'magma')
#       3 ax.set_xlabel(xlabel = 'Names of some popular Clubs', fontsize = 10)
#       4 ax.set_ylabel(ylabel = 'Distribution', fontsize = 10)
#       5 ax.set_title(label = 'Disstribution of Ages in some Popular Clubs', fontsize = 20)
#
# NameError: name 'data_club' is not defined

# %%
some_clubs = ('CD Leganés', 'Southampton', 'RC Celta', 'Empoli', 'Fortuna Düsseldorf', 'Manchestar City',
             'Tottenham Hotspur', 'FC Barcelona', 'Valencia CF', 'Chelsea', 'Real Madrid')

data_club = data.loc[data['Club'].isin(some_clubs) & data['Wage']]

plt.rcParams['figure.figsize'] = (15, 8)
ax = sns.boxenplot(x = 'Club', y = 'Age', data = data_club, palette = 'magma')
ax.set_xlabel(xlabel = 'Names of some popular Clubs', fontsize = 10)
ax.set_ylabel(ylabel = 'Distribution', fontsize = 10)
ax.set_title(label = 'Disstribution of Ages in some Popular Clubs', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
data['Club'].value_counts()
#most pop

# %%
#Top 10 left footed footballers

data[data['Preferred Foot'] == 'Left'][['Name', 'Age', 'Club', 'Nationality']].head(10).style.background_gradient('magma')

# %%
data[data['Preferred Foot'] == 'Right'][['Name', 'Age', 'Club', 'Nationality']].head(10).style.background_gradient('copper')
# Out:
# <style  type="text/css" >
# #T_58b3db86_61b2_11ec_85ea_040e3cdbb745row0_col1{
#             background-color:  #ffc77f;
#             color:  #000000;
#         }#T_58b3db86_61b2_11ec_85ea_040e3cdbb745row1_col1{
#             background-color:  #281910;
#             color:  #f1f1f1;
#         }#T_58b3db86_61b2_11ec_85ea_040e3cdbb745row2_col1,#T_58b3db86_61b2_11ec_85ea_040e3cdbb745row3_col1,#T_58b3db86_61b2_11ec_85ea_040e3cdbb745row4_col1{
#             background-color:  #4f3220;
#             color:  #f1f1f1;
#         }#T_58b3db86_61b2_11ec_85ea_040e3cdbb745row5_col1,#T_58b3db86_61b2_11ec_85ea_040e3cdbb745row7_col1{
#             background-color:  #ffaf6f;
#             color:  #000000;
#         }#T_58b3db86_61b2_11ec_85ea_040e3cdbb745row6_col1{
#             background-color:  #ed9660;
#             color:  #000000;
#         }#T_58b3db86_61b2_11ec_85ea_040e3cdbb745row8_col1{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_58b3db86_61b2_11ec_85ea_040e3cdbb745row9_col1{
#             background-color:  #9e6440;
#             color:  #000000;
#         }</style><table id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Age</th>        <th class="col_heading level0 col2" >Club</th>        <th class="col_heading level0 col3" >Nationality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row0_col0" class="data row0 col0" >Cristiano Ronaldo</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row0_col1" class="data row0 col1" >33</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row0_col2" class="data row0 col2" >Juventus</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row0_col3" class="data row0 col3" >Portugal</td>
#             </tr>
#             <tr>
#                         <th id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row1_col0" class="data row1 col0" >Neymar Jr</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row1_col1" class="data row1 col1" >26</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row1_col2" class="data row1 col2" >Paris Saint-Germain</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row1_col3" class="data row1 col3" >Brazil</td>
#             </tr>
#             <tr>
#                         <th id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row2_col0" class="data row2 col0" >De Gea</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row2_col1" class="data row2 col1" >27</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row2_col2" class="data row2 col2" >Manchester United</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row2_col3" class="data row2 col3" >Spain</td>
#             </tr>
#             <tr>
#                         <th id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row3_col0" class="data row3 col0" >K. De Bruyne</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row3_col1" class="data row3 col1" >27</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row3_col2" class="data row3 col2" >Manchester City</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row3_col3" class="data row3 col3" >Belgium</td>
#             </tr>
#             <tr>
#                         <th id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row4_col0" class="data row4 col0" >E. Hazard</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row4_col1" class="data row4 col1" >27</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row4_col2" class="data row4 col2" >Chelsea</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row4_col3" class="data row4 col3" >Belgium</td>
#             </tr>
#             <tr>
#                         <th id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row5_col0" class="data row5 col0" >L. Modrić</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row5_col1" class="data row5 col1" >32</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row5_col2" class="data row5 col2" >Real Madrid</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row5_col3" class="data row5 col3" >Croatia</td>
#             </tr>
#             <tr>
#                         <th id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row6_col0" class="data row6 col0" >L. Suárez</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row6_col1" class="data row6 col1" >31</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row6_col2" class="data row6 col2" >FC Barcelona</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row6_col3" class="data row6 col3" >Uruguay</td>
#             </tr>
#             <tr>
#                         <th id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row7_col0" class="data row7 col0" >Sergio Ramos</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row7_col1" class="data row7 col1" >32</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row7_col2" class="data row7 col2" >Real Madrid</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row7_col3" class="data row7 col3" >Spain</td>
#             </tr>
#             <tr>
#                         <th id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row8_col0" class="data row8 col0" >J. Oblak</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row8_col1" class="data row8 col1" >25</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row8_col2" class="data row8 col2" >Atlético Madrid</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row8_col3" class="data row8 col3" >Slovenia</td>
#             </tr>
#             <tr>
#                         <th id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row9_col0" class="data row9 col0" >R. Lewandowski</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row9_col1" class="data row9 col1" >29</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row9_col2" class="data row9 col2" >FC Bayern München</td>
#                         <td id="T_58b3db86_61b2_11ec_85ea_040e3cdbb745row9_col3" class="data row9 col3" >Poland</td>
#             </tr>
#     </tbody></table>
